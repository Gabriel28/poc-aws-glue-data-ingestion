# %%
import gc
import os
import pandas as pd
import json
import awswrangler as wr
import boto3 as boto3
from dotenv import load_dotenv
from pandas import json_normalize, DataFrame
from concurrent.futures import ThreadPoolExecutor

print("""
    POC para criação de um dataframe a partir de vários arquivos .json coletados simulando um bucketS3.
""")

# Configurar região no Wrangler
wr.config.region = 'us-east-1'
load_dotenv()
database = os.getenv('DATABASE')
path_bucket = os.getenv('PATH_BUCKET')
table_name = os.getenv('TABLE_NAME')

class Boto3Client:
    @staticmethod
    def boto_client(service_name: str):
        session = boto3.Session()
        credentials = session.get_credentials()
        return session.client(
            service_name=service_name,
            aws_access_key_id=credentials.access_key,
            aws_secret_access_key=credentials.secret_key,
            aws_session_token=credentials.token,
            region_name='us-east-1'
        )

# Processa os JSON de cada diretoria e normaliza sem passar pela df do wr
def process_file(file_path) -> DataFrame:
    try:
        with open(file_path, 'r', encoding='utf-8') as json_file:
            data = json.load(json_file)
            data['additionals'] = json.dumps(data['additionals'])
            df = json_normalize(data, max_level=0)
            return df
    except (json.JSONDecodeError, OSError) as e:
        print(f"Aqui deu ruim {file_path}: {e}")
        return DataFrame()

def get_all_files(base_path):
    for root, _, files in os.walk(base_path):
        for file in files:
            if file.lower().endswith('.json'):
                yield os.path.join(root, file)

def process_json_files(base_path) -> DataFrame:
    file_paths = get_all_files(base_path)
    with ThreadPoolExecutor() as executor:
        dataframes = executor.map(process_file, file_paths)

    df_united = DataFrame()
    for df in dataframes:
        if not df.empty:
            df_united = pd.concat([df_united, df], ignore_index=True)

    if df_united.empty:
        print("Aqui acabou")
    return df_united

def save_dataframe(df):
    wr.s3.to_parquet(
        df=df,
        path=path_bucket,
        dataset=True,
        database=database,
        table=table_name,
        compression="snappy",
        partition_cols=['year', 'month', 'day'],
        mode="overwrite_partitions"
    )
    gc.collect()

# Verifica se a tabela no Glue existe
def check_glue_table():
    glue_client = Boto3Client.boto_client("glue")
    try:
        response = glue_client.get_table(DatabaseName=database, Name=table_name)
        print("TODA A INFO:", response)
    except glue_client.exceptions.EntityNotFoundException:
        print("NADA ENCONTRADO.. ")
        # Aqui você pode adicionar lógica para criar a tabela no Glue, se necessário.
    except glue_client.exceptions.AccessDeniedException:
        print("VOCÊ NÃO TEM PERMISSÃO, VOLTE DUAS CASAS")
    except Exception as e:
        print(f"AQUI ACABOU GAROTINHO {e}")

# Inicia o processo
if __name__ == "__main__":
    check_glue_table()
    df = process_json_files('resources')
    if not df.empty:
        save_dataframe(df)
        print(f"Dataframe saved successfully")
# Out:
# Dados antes da normalização
#  {'accountID': '3907742878934', 'stage': 'execution', 'product': 'product1', 'additionals': '{"info": "extra data", "repository": "github-exemple"}', 'year': '2024', 'month': '12', 'day': '17', 'hour': '14'}
#
# Dados pós normalização:
#         accountID      stage   product  \
# 0  3907742878934  execution  product1
#
#                                          additionals  year month day hour
# 0  {"info": "extra data", "repository": "github-e...  2024    12  17   14
#
# Dados antes da normalização
#  {'accountID': '78917823971897', 'stage': 'execution', 'product': 'product2', 'additionals': '{"info": "extra data", "repository": "github-exemple-2"}', 'year': '2024', 'month': '12', 'day': '19', 'hour': '15'}
#
# Dados pós normalização:
#          accountID      stage   product  \
# 0  78917823971897  execution  product2
#
#                                          additionals  year month day hour
# 0  {"info": "extra data", "repository": "github-e...  2024    12  19   15
#
# Dados antes da normalização
#  {'accountID': '17897197891892', 'stage': 'execution', 'product': 'product3', 'additionals': '{"info": "extra data", "repository": "github-exemple-3", "error": "AlreadyExists"}', 'year': '2024', 'month': '12', 'day': '23', 'hour': '11'}
#
# Dados pós normalização:
#          accountID      stage   product  \
# 0  17897197891892  execution  product3
#
#                                          additionals  year month day hour
# 0  {"info": "extra data", "repository": "github-e...  2024    12  23   11
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Cell In[12], line 83
#      81 df = process_json_files('resources')
#      82 if not df.empty:
# ---> 83     save_dataframe(df)
#
# Cell In[12], line 66, in save_dataframe(df)
#      64 def save_dataframe(df):
#      65     wr.config.region_name = 'us-east-1'
# ---> 66     wr.s3.to_parquet(
#      67         df=df,
#      68         path="s3://ts3-sandbox/",
#      69         dataset=True,
#      70         database="db_local_home_test",
#      71         table="teste_ingestao_coletora",
#      72         compression="snappy",
#      73         partition_cols=['year', 'month', 'day'],
#      74         mode="overwrite_partitions"
#      75     )
#      76     gc.collect()
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\awswrangler\_config.py:712, in apply_configs.<locals>.wrapper(*args_raw, **kwargs)
#     710         del args[name]
#     711         args = {**args, **keywords}
# --> 712 return function(**args)
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\awswrangler\_utils.py:179, in validate_kwargs.<locals>.decorator.<locals>.inner(*args, **kwargs)
#     176 if condition_fn() and len(passed_unsupported_kwargs) > 0:
#     177     raise exceptions.InvalidArgument(f"{message} `{', '.join(passed_unsupported_kwargs)}`.")
# --> 179 return func(*args, **kwargs)
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\awswrangler\s3\_write_parquet.py:723, in to_parquet(df, path, index, compression, pyarrow_additional_kwargs, max_rows_by_file, use_threads, boto3_session, s3_additional_kwargs, sanitize_columns, dataset, filename_prefix, partition_cols, bucketing_info, concurrent_partitioning, mode, catalog_versioning, schema_evolution, database, table, glue_table_settings, dtype, athena_partition_projection_settings, catalog_id, encryption_configuration)
#     720     pyarrow_additional_kwargs["flavor"] = "spark"
#     722 strategy = _S3ParquetWriteStrategy()
# --> 723 return strategy.write(
#     724     df=df,
#     725     path=path,
#     726     index=index,
#     727     compression=compression,
#     728     pyarrow_additional_kwargs=pyarrow_additional_kwargs,
#     729     max_rows_by_file=max_rows_by_file,
#     730     use_threads=use_threads,
#     731     boto3_session=boto3_session,
#     732     s3_additional_kwargs=s3_additional_kwargs,
#     733     sanitize_columns=sanitize_columns,
#     734     dataset=dataset,
#     735     filename_prefix=filename_prefix,
#     736     partition_cols=partition_cols,
#     737     bucketing_info=bucketing_info,
#     738     concurrent_partitioning=concurrent_partitioning,
#     739     mode=mode,
#     740     catalog_versioning=catalog_versioning,
#     741     schema_evolution=schema_evolution,
#     742     database=database,
#     743     table=table,
#     744     description=description,
#     745     parameters=parameters,
#     746     columns_comments=columns_comments,
#     747     columns_parameters=columns_parameters,
#     748     table_type=table_type,
#     749     regular_partitions=regular_partitions,
#     750     dtype=dtype,
#     751     athena_partition_projection_settings=athena_partition_projection_settings,
#     752     catalog_id=catalog_id,
#     753     compression_ext=compression_ext,
#     754     encryption_configuration=encryption_configuration,
#     755 )
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\awswrangler\s3\_write.py:298, in _S3WriteStrategy.write(self, df, path, index, compression, pyarrow_additional_kwargs, max_rows_by_file, use_threads, boto3_session, s3_additional_kwargs, sanitize_columns, dataset, filename_prefix, partition_cols, bucketing_info, concurrent_partitioning, mode, catalog_versioning, schema_evolution, database, table, description, parameters, columns_comments, columns_parameters, regular_partitions, table_type, dtype, athena_partition_projection_settings, catalog_id, compression_ext, encryption_configuration)
#     296 catalog_table_input: dict[str, Any] | None = None
#     297 if database is not None and table is not None:
# --> 298     catalog_table_input = catalog._get_table_input(
#     299         database=database,
#     300         table=table,
#     301         boto3_session=boto3_session,
#     302         catalog_id=catalog_id,
#     303     )
#     304     catalog_path: str | None = None
#     305     if catalog_table_input:
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\awswrangler\catalog\_get.py:30, in _get_table_input(database, table, boto3_session, catalog_id)
#      24 def _get_table_input(
#      25     database: str,
#      26     table: str,
#      27     boto3_session: boto3.Session | None,
#      28     catalog_id: str | None = None,
#      29 ) -> dict[str, Any] | None:
# ---> 30     client_glue = _utils.client("glue", session=boto3_session)
#      31     args: dict[str, Any] = _catalog_id(catalog_id=catalog_id, DatabaseName=database, Name=table)
#      32     try:
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\awswrangler\_config.py:712, in apply_configs.<locals>.wrapper(*args_raw, **kwargs)
#     710         del args[name]
#     711         args = {**args, **keywords}
# --> 712 return function(**args)
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\awswrangler\_utils.py:480, in client(service_name, session, botocore_config, verify)
#     478 """Create a valid boto3.client."""
#     479 endpoint_url: str | None = _get_endpoint_url(service_name=service_name)
# --> 480 return ensure_session(session=session).client(
#     481     service_name=service_name,
#     482     endpoint_url=endpoint_url,
#     483     use_ssl=True,
#     484     config=botocore_config or default_botocore_config(),
#     485     verify=verify or _config.config.verify,
#     486 )
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\boto3\session.py:297, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     215 def client(
#     216     self,
#     217     service_name,
#    (...)
#     226     config=None,
#     227 ):
#     228     """
#     229     Create a low-level service client by name.
#     230
#    (...)
#     295
#     296     """
# --> 297     return self._session.create_client(
#     298         service_name,
#     299         region_name=region_name,
#     300         api_version=api_version,
#     301         use_ssl=use_ssl,
#     302         verify=verify,
#     303         endpoint_url=endpoint_url,
#     304         aws_access_key_id=aws_access_key_id,
#     305         aws_secret_access_key=aws_secret_access_key,
#     306         aws_session_token=aws_session_token,
#     307         config=config,
#     308     )
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\session.py:997, in Session.create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     980 self._add_configured_endpoint_provider(
#     981     client_name=service_name,
#     982     config_store=config_store,
#     983 )
#     985 client_creator = botocore.client.ClientCreator(
#     986     loader,
#     987     endpoint_resolver,
#    (...)
#     995     user_agent_creator=user_agent_creator,
#     996 )
# --> 997 client = client_creator.create_client(
#     998     service_name=service_name,
#     999     region_name=region_name,
#    1000     is_secure=use_ssl,
#    1001     endpoint_url=endpoint_url,
#    1002     verify=verify,
#    1003     credentials=credentials,
#    1004     scoped_config=self.get_scoped_config(),
#    1005     client_config=config,
#    1006     api_version=api_version,
#    1007     auth_token=auth_token,
#    1008 )
#    1009 monitor = self._get_internal_component('monitor')
#    1010 if monitor is not None:
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\client.py:165, in ClientCreator.create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config, auth_token)
#     154     service_signature_version = service_model.metadata.get(
#     155         'signatureVersion'
#     156     )
#     157 endpoint_bridge = ClientEndpointBridge(
#     158     self._endpoint_resolver,
#     159     scoped_config,
#    (...)
#     163     service_signature_version=service_signature_version,
#     164 )
# --> 165 client_args = self._get_client_args(
#     166     service_model,
#     167     region_name,
#     168     is_secure,
#     169     endpoint_url,
#     170     verify,
#     171     credentials,
#     172     scoped_config,
#     173     client_config,
#     174     endpoint_bridge,
#     175     auth_token,
#     176     endpoints_ruleset_data,
#     177     partition_data,
#     178 )
#     179 service_client = cls(**client_args)
#     180 self._register_retries(service_client)
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\client.py:524, in ClientCreator._get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     500 def _get_client_args(
#     501     self,
#     502     service_model,
#    (...)
#     513     partition_data,
#     514 ):
#     515     args_creator = ClientArgsCreator(
#     516         self._event_emitter,
#     517         self._user_agent,
#    (...)
#     522         user_agent_creator=self._user_agent_creator,
#     523     )
# --> 524     return args_creator.get_client_args(
#     525         service_model,
#     526         region_name,
#     527         is_secure,
#     528         endpoint_url,
#     529         verify,
#     530         credentials,
#     531         scoped_config,
#     532         client_config,
#     533         endpoint_bridge,
#     534         auth_token,
#     535         endpoints_ruleset_data,
#     536         partition_data,
#     537     )
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\args.py:101, in ClientArgsCreator.get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#      86 def get_client_args(
#      87     self,
#      88     service_model,
#    (...)
#      99     partition_data=None,
#     100 ):
# --> 101     final_args = self.compute_client_args(
#     102         service_model,
#     103         client_config,
#     104         endpoint_bridge,
#     105         region_name,
#     106         endpoint_url,
#     107         is_secure,
#     108         scoped_config,
#     109     )
#     111     service_name = final_args['service_name']  # noqa
#     112     parameter_validation = final_args['parameter_validation']
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\args.py:220, in ClientArgsCreator.compute_client_args(self, service_model, client_config, endpoint_bridge, region_name, endpoint_url, is_secure, scoped_config)
#     213 s3_config = self.compute_s3_config(client_config)
#     215 configured_endpoint_url = self._compute_configured_endpoint_url(
#     216     client_config=client_config,
#     217     endpoint_url=endpoint_url,
#     218 )
# --> 220 endpoint_config = self._compute_endpoint_config(
#     221     service_name=service_name,
#     222     region_name=region_name,
#     223     endpoint_url=configured_endpoint_url,
#     224     is_secure=is_secure,
#     225     endpoint_bridge=endpoint_bridge,
#     226     s3_config=s3_config,
#     227 )
#     228 endpoint_variant_tags = endpoint_config['metadata'].get('tags', [])
#     230 # Some third-party libraries expect the final user-agent string in
#     231 # ``client.meta.config.user_agent``. To maintain backwards
#     232 # compatibility, the preliminary user-agent string (before any Config
#     233 # object modifications and without request-specific user-agent
#     234 # components) is stored in the new Config object's ``user_agent``
#     235 # property but not used by Botocore itself.
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\args.py:374, in ClientArgsCreator._compute_endpoint_config(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge, s3_config)
#     372 if service_name == 'sts':
#     373     return self._compute_sts_endpoint_config(**resolve_endpoint_kwargs)
# --> 374 return self._resolve_endpoint(**resolve_endpoint_kwargs)
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\args.py:479, in ClientArgsCreator._resolve_endpoint(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge)
#     471 def _resolve_endpoint(
#     472     self,
#     473     service_name,
#    (...)
#     477     endpoint_bridge,
#     478 ):
# --> 479     return endpoint_bridge.resolve(
#     480         service_name, region_name, endpoint_url, is_secure
#     481     )
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\client.py:629, in ClientEndpointBridge.resolve(self, service_name, region_name, endpoint_url, is_secure)
#     623 use_dualstack_endpoint = self._resolve_use_dualstack_endpoint(
#     624     service_name
#     625 )
#     626 use_fips_endpoint = self._resolve_endpoint_variant_config_var(
#     627     'use_fips_endpoint'
#     628 )
# --> 629 resolved = self.endpoint_resolver.construct_endpoint(
#     630     service_name,
#     631     region_name,
#     632     use_dualstack_endpoint=use_dualstack_endpoint,
#     633     use_fips_endpoint=use_fips_endpoint,
#     634 )
#     636 # If we can't resolve the region, we'll attempt to get a global
#     637 # endpoint for non-regionalized services (iam, route53, etc)
#     638 if not resolved:
#     639     # TODO: fallback partition_name should be configurable in the
#     640     # future for users to define as needed.
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\regions.py:232, in EndpointResolver.construct_endpoint(self, service_name, region_name, partition_name, use_dualstack_endpoint, use_fips_endpoint)
#     227 if use_dualstack_endpoint and (
#     228     partition['partition']
#     229     in self._UNSUPPORTED_DUALSTACK_PARTITIONS
#     230 ):
#     231     continue
# --> 232 result = self._endpoint_for_partition(
#     233     partition,
#     234     service_name,
#     235     region_name,
#     236     use_dualstack_endpoint,
#     237     use_fips_endpoint,
#     238 )
#     239 if result:
#     240     return result
#
# File ~\PycharmProjects\AWS\lambdaProject\.venv\Lib\site-packages\botocore\regions.py:280, in EndpointResolver._endpoint_for_partition(self, partition, service_name, region_name, use_dualstack_endpoint, use_fips_endpoint, force_partition)
#     278         region_name = service_data['partitionEndpoint']
#     279     else:
# --> 280         raise NoRegionError()
#     282 resolve_kwargs = {
#     283     'partition': partition,
#     284     'service_name': service_name,
#    (...)
#     288     'use_fips_endpoint': use_fips_endpoint,
#     289 }
#     291 # Attempt to resolve the exact region for this partition.
#
# NoRegionError: You must specify a region.
